# %%
#Setting up the environment

import pandas as pd
import numpy as np
import os

# %%
#Create a path
path = r'C:\Users\manny\Documents\Instacart Basket Analysis 05-01-2023'

# %%
#import dataframe -ords_prods_merge
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# #### Task 4.8

# %% [markdown]
# #### 2.In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
df_ords_prods_merge.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #### 3.Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# The subset had limited number of department id compared to the full dataframe which has more,

# %% [markdown]
# #### 4.Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
#Transform function
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#check output
df_ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# 14           151           151    487368       15            22
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                    2                  8                     NaN         196
# 1                    3                  7                    15.0         196
# 2                    3                 12                    21.0         196
# 3                    4                  7                    29.0         196
# 4                    4                 15                    28.0         196
# 5                    2                  7                    19.0         196
# 6                    1                  9                    20.0         196
# 7                    1                 14                    14.0         196
# 8                    1                 16                     0.0         196
# 9                    4                  8                    30.0         196
# 10                   1                  9                     7.0         196
# 11                   2                 16                     8.0         196
# 12                   2                 11                     7.0         196
# 13                   1                  9                     7.0         196
# 14                   1                 10                    14.0         196
#
#     add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# 0                   1          0           195         Soda        77
# 1                   1          1           195         Soda        77
# 2                   1          1           195         Soda        77
# 3                   1          1           195         Soda        77
# 4                   1          1           195         Soda        77
# 5                   1          1           195         Soda        77
# 6                   1          1           195         Soda        77
# 7                   2          1           195         Soda        77
# 8                   4          1           195         Soda        77
# 9                   1          1           195         Soda        77
# 10                  2          0           195         Soda        77
# 11                  6          1           195         Soda        77
# 12                  1          1           195         Soda        77
# 13                  1          1           195         Soda        77
# 14                  1          1           195         Soda        77
#
#     department_id  prices _merge  max_order
# 0               7     9.0   both         10
# 1               7     9.0   both         10
# 2               7     9.0   both         10
# 3               7     9.0   both         10
# 4               7     9.0   both         10
# 5               7     9.0   both         10
# 6               7     9.0   both         10
# 7               7     9.0   both         10
# 8               7     9.0   both         10
# 9               7     9.0   both         10
# 10              7     9.0   both         22
# 11              7     9.0   both         22
# 12              7     9.0   both         22
# 13              7     9.0   both         22
# 14              7     9.0   both         22

# %%
df_ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# ..           ...           ...       ...      ...           ...
# 95          5895          5895   3226575      360             1
# 96          6137          6137   1469869      377             3
# 97          6259          6259   1927023      387             2
# 98          6740          6740    858092      420             4
# 99          6741          6741    119314      420             5
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                    2                  8                     NaN         196
# 1                    3                  7                    15.0         196
# 2                    3                 12                    21.0         196
# 3                    4                  7                    29.0         196
# 4                    4                 15                    28.0         196
# ..                 ...                ...                     ...         ...
# 95                   5                 12                     NaN         196
# 96                   5                 17                     3.0         196
# 97                   4                 10                    22.0         196
# 98                   1                 19                    30.0         196
# 99                   3                 19                    16.0         196
#
#     add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# 0                   1          0           195         Soda        77
# 1                   1          1           195         Soda        77
# 2                   1          1           195         Soda        77
# 3                   1          1           195         Soda        77
# 4                   1          1           195         Soda        77
# ..                ...        ...           ...          ...       ...
# 95                  1          0           195         Soda        77
# 96                  9          0           195         Soda        77
# 97                  3          0           195         Soda        77
# 98                  2          0           195         Soda        77
# 99                  2          1           195         Soda        77
#
#     department_id  prices _merge  max_order
# 0               7     9.0   both         10
# 1               7     9.0   both         10
# 2               7     9.0   both         10
# 3               7     9.0   both         10
# 4               7     9.0   both         10
# ..            ...     ...    ...        ...
# 95              7     9.0   both          3
# 96              7     9.0   both          3
# 97              7     9.0   both          8
# 98              7     9.0   both         22
# 99              7     9.0   both         22
#
# [100 rows x 18 columns]

# %% [markdown]
# #### loc () function

# %%
#If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”

df_ords_prods_merge.loc[df_ords_prods_merge['max_order']>40, 'loyalty_flag'] = 'loyal_customer'

# %%
#If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”

df_ords_prods_merge.loc[(df_ords_prods_merge['max_order']>10) &(df_ords_prods_merge['max_order']<=40) , 'loyalty_flag'] = 'regular_customer'

# %%
# If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

df_ords_prods_merge.loc[df_ords_prods_merge['max_order']<=10, 'loyalty_flag'] = 'new_customer'

# %%
#Value counts
df_ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# regular_customer    15876776
# loyal_customer      10284093
# new_customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#Check Output
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      new_customer             1
# 1         1      new_customer             2
# 2         1      new_customer             3
# 3         1      new_customer             4
# 4         1      new_customer             5
# 5         1      new_customer             6
# 6         1      new_customer             7
# 7         1      new_customer             8
# 8         1      new_customer             9
# 9         1      new_customer            10
# 10       15  regular_customer            15
# 11       15  regular_customer            17
# 12       15  regular_customer            18
# 13       15  regular_customer            21
# 14       15  regular_customer            22
# 15       19      new_customer             2
# 16       19      new_customer             5
# 17       19      new_customer             7
# 18       21  regular_customer            10
# 19       31  regular_customer            10
# 20       31  regular_customer            17
# 21       43  regular_customer             6
# 22       43  regular_customer             9
# 23       52  regular_customer             1
# 24       52  regular_customer             2
# 25       52  regular_customer             3
# 26       52  regular_customer             5
# 27       52  regular_customer             7
# 28       52  regular_customer             9
# 29       52  regular_customer            10
# 30       52  regular_customer            11
# 31       52  regular_customer            12
# 32       52  regular_customer            15
# 33       52  regular_customer            17
# 34       52  regular_customer            18
# 35       52  regular_customer            19
# 36       52  regular_customer            21
# 37       67  regular_customer             1
# 38       67  regular_customer             2
# 39       67  regular_customer             3
# 40       67  regular_customer             4
# 41       67  regular_customer             5
# 42       67  regular_customer             6
# 43       67  regular_customer             8
# 44       67  regular_customer             9
# 45       67  regular_customer            10
# 46       67  regular_customer            11
# 47       67  regular_customer            12
# 48       67  regular_customer            13
# 49       67  regular_customer            14
# 50       67  regular_customer            16
# 51       67  regular_customer            18
# 52       67  regular_customer            19
# 53       67  regular_customer            21
# 54       67  regular_customer            22
# 55       67  regular_customer            23
# 56       81      new_customer             3
# 57       81      new_customer             5
# 58       82  regular_customer             1
# 59       82  regular_customer             3

# %% [markdown]
# #### 5.The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
#Full Dataframe; mean, min, max
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# loyal_customer    10.386336  1.0  99999.0
# new_customer      13.294670  1.0  99999.0
# regular_customer  12.495717  1.0  99999.0

# %% [markdown]
# There is a difference in mean prices of each customer based on their loyalty.
# New customers on average paid the most followed by regular and then loyal customers.

# %% [markdown]
# #### 6. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria

# %%
#Transform function
df_ords_prods_merge['avg_ord_prices'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#check output
df_ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# 14           151           151    487368       15            22
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                    2                  8                     NaN         196
# 1                    3                  7                    15.0         196
# 2                    3                 12                    21.0         196
# 3                    4                  7                    29.0         196
# 4                    4                 15                    28.0         196
# 5                    2                  7                    19.0         196
# 6                    1                  9                    20.0         196
# 7                    1                 14                    14.0         196
# 8                    1                 16                     0.0         196
# 9                    4                  8                    30.0         196
# 10                   1                  9                     7.0         196
# 11                   2                 16                     8.0         196
# 12                   2                 11                     7.0         196
# 13                   1                  9                     7.0         196
# 14                   1                 10                    14.0         196
#
#     add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# 0                   1          0           195         Soda        77
# 1                   1          1           195         Soda        77
# 2                   1          1           195         Soda        77
# 3                   1          1           195         Soda        77
# 4                   1          1           195         Soda        77
# 5                   1          1           195         Soda        77
# 6                   1          1           195         Soda        77
# 7                   2          1           195         Soda        77
# 8                   4          1           195         Soda        77
# 9                   1          1           195         Soda        77
# 10                  2          0           195         Soda        77
# 11                  6          1           195         Soda        77
# 12                  1          1           195         Soda        77
# 13                  1          1           195         Soda        77
# 14                  1          1           195         Soda        77
#
#     department_id  prices _merge  max_order      loyalty_flag  avg_ord_prices
# 0               7     9.0   both         10      new_customer        6.367797
# 1               7     9.0   both         10      new_customer        6.367797
# 2               7     9.0   both         10      new_customer        6.367797
# 3               7     9.0   both         10      new_customer        6.367797
# 4               7     9.0   both         10      new_customer        6.367797
# 5               7     9.0   both         10      new_customer        6.367797
# 6               7     9.0   both         10      new_customer        6.367797
# 7               7     9.0   both         10      new_customer        6.367797
# 8               7     9.0   both         10      new_customer        6.367797
# 9               7     9.0   both         10      new_customer        6.367797
# 10              7     9.0   both         22  regular_customer        3.980556
# 11              7     9.0   both         22  regular_customer        3.980556
# 12              7     9.0   both         22  regular_customer        3.980556
# 13              7     9.0   both         22  regular_customer        3.980556
# 14              7     9.0   both         22  regular_customer        3.980556

# %%
#If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”

df_ords_prods_merge.loc[df_ords_prods_merge['avg_ord_prices']<10, 'spending_flag'] = 'low_spender'

# %%
#If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender."

df_ords_prods_merge.loc[df_ords_prods_merge['avg_ord_prices']>=10, 'spending_flag'] = 'high_spender'

# %%
#check output
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0             0             0   2539329        1             1
# 1             1             1   2398795        1             2
# 2             2             2    473747        1             3
# 3             3             3   2254736        1             4
# 4             4             4    431534        1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                     NaN         196
# 1                   3                  7                    15.0         196
# 2                   3                 12                    21.0         196
# 3                   4                  7                    29.0         196
# 4                   4                 15                    28.0         196
#
#    add_to_cart_order  ...  Unnamed: 0_y  product_name aisle_id  department_id  \
# 0                  1  ...           195          Soda       77              7
# 1                  1  ...           195          Soda       77              7
# 2                  1  ...           195          Soda       77              7
# 3                  1  ...           195          Soda       77              7
# 4                  1  ...           195          Soda       77              7
#
#    prices  _merge max_order  loyalty_flag avg_ord_prices  spending_flag
# 0     9.0    both        10  new_customer       6.367797    low_spender
# 1     9.0    both        10  new_customer       6.367797    low_spender
# 2     9.0    both        10  new_customer       6.367797    low_spender
# 3     9.0    both        10  new_customer       6.367797    low_spender
# 4     9.0    both        10  new_customer       6.367797    low_spender
#
# [5 rows x 21 columns]

# %%
#value counts on spending flag
df_ords_prods_merge['spending_flag'].value_counts(dropna=False)
# Out:
# low_spender     31770614
# high_spender      634245
# Name: spending_flag, dtype: int64

# %%
#Check for shape
df_ords_prods_merge.shape
# Out:
# (32404859, 21)

# %% [markdown]
# #### 7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:

# %%
#Transform function
df_ords_prods_merge['med_freq'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#check output
df_ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# 14           151           151    487368       15            22
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                    2                  8                     NaN         196
# 1                    3                  7                    15.0         196
# 2                    3                 12                    21.0         196
# 3                    4                  7                    29.0         196
# 4                    4                 15                    28.0         196
# 5                    2                  7                    19.0         196
# 6                    1                  9                    20.0         196
# 7                    1                 14                    14.0         196
# 8                    1                 16                     0.0         196
# 9                    4                  8                    30.0         196
# 10                   1                  9                     7.0         196
# 11                   2                 16                     8.0         196
# 12                   2                 11                     7.0         196
# 13                   1                  9                     7.0         196
# 14                   1                 10                    14.0         196
#
#     add_to_cart_order  ...  aisle_id  department_id prices  _merge  max_order  \
# 0                   1  ...        77              7    9.0    both         10
# 1                   1  ...        77              7    9.0    both         10
# 2                   1  ...        77              7    9.0    both         10
# 3                   1  ...        77              7    9.0    both         10
# 4                   1  ...        77              7    9.0    both         10
# 5                   1  ...        77              7    9.0    both         10
# 6                   1  ...        77              7    9.0    both         10
# 7                   2  ...        77              7    9.0    both         10
# 8                   4  ...        77              7    9.0    both         10
# 9                   1  ...        77              7    9.0    both         10
# 10                  2  ...        77              7    9.0    both         22
# 11                  6  ...        77              7    9.0    both         22
# 12                  1  ...        77              7    9.0    both         22
# 13                  1  ...        77              7    9.0    both         22
# 14                  1  ...        77              7    9.0    both         22
#
#         loyalty_flag avg_ord_prices  spending_flag  \
# 0       new_customer       6.367797    low_spender
# 1       new_customer       6.367797    low_spender
# 2       new_customer       6.367797    low_spender
# 3       new_customer       6.367797    low_spender
# 4       new_customer       6.367797    low_spender
# 5       new_customer       6.367797    low_spender
# 6       new_customer       6.367797    low_spender
# 7       new_customer       6.367797    low_spender
# 8       new_customer       6.367797    low_spender
# 9       new_customer       6.367797    low_spender
# 10  regular_customer       3.980556    low_spender
# 11  regular_customer       3.980556    low_spender
# 12  regular_customer       3.980556    low_spender
# 13  regular_customer       3.980556    low_spender
# 14  regular_customer       3.980556    low_spender
#
#    median_days_since_prior_order  med_freq
# 0                           20.5      20.5
# 1                           20.5      20.5
# 2                           20.5      20.5
# 3                           20.5      20.5
# 4                           20.5      20.5
# 5                           20.5      20.5
# 6                           20.5      20.5
# 7                           20.5      20.5
# 8                           20.5      20.5
# 9                           20.5      20.5
# 10                          10.0      10.0
# 11                          10.0      10.0
# 12                          10.0      10.0
# 13                          10.0      10.0
# 14                          10.0      10.0
#
# [15 rows x 23 columns]

# %%
#If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.

df_ords_prods_merge.loc[df_ords_prods_merge['med_freq']>20, 'customer_frequency'] = 'non-frequent_customer'

# %%
#If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”

df_ords_prods_merge.loc[(df_ords_prods_merge['med_freq']>10)&(df_ords_prods_merge['med_freq']<=20),'customer_frequency'] = 'regular_customer'

# %%
#If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

df_ords_prods_merge.loc[df_ords_prods_merge['med_freq']<=10, 'customer_frequency'] = 'frequent_customer'

# %%
#Check Output
df_ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id  order_number  \
# 0              0             0   2539329        1             1
# 1              1             1   2398795        1             2
# 2              2             2    473747        1             3
# 3              3             3   2254736        1             4
# 4              4             4    431534        1             5
# 5              5             5   3367565        1             6
# 6              6             6    550135        1             7
# 7              7             7   3108588        1             8
# 8              8             8   2295261        1             9
# 9              9             9   2550362        1            10
# 10           144           144   2968173       15            15
# 11           146           146   1870022       15            17
# 12           147           147   1911383       15            18
# 13           150           150   2715276       15            21
# 14           151           151    487368       15            22
#
#     orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                    2                  8                     NaN         196
# 1                    3                  7                    15.0         196
# 2                    3                 12                    21.0         196
# 3                    4                  7                    29.0         196
# 4                    4                 15                    28.0         196
# 5                    2                  7                    19.0         196
# 6                    1                  9                    20.0         196
# 7                    1                 14                    14.0         196
# 8                    1                 16                     0.0         196
# 9                    4                  8                    30.0         196
# 10                   1                  9                     7.0         196
# 11                   2                 16                     8.0         196
# 12                   2                 11                     7.0         196
# 13                   1                  9                     7.0         196
# 14                   1                 10                    14.0         196
#
#     add_to_cart_order  ...  department_id  prices _merge  max_order  \
# 0                   1  ...              7     9.0   both         10
# 1                   1  ...              7     9.0   both         10
# 2                   1  ...              7     9.0   both         10
# 3                   1  ...              7     9.0   both         10
# 4                   1  ...              7     9.0   both         10
# 5                   1  ...              7     9.0   both         10
# 6                   1  ...              7     9.0   both         10
# 7                   2  ...              7     9.0   both         10
# 8                   4  ...              7     9.0   both         10
# 9                   1  ...              7     9.0   both         10
# 10                  2  ...              7     9.0   both         22
# 11                  6  ...              7     9.0   both         22
# 12                  1  ...              7     9.0   both         22
# 13                  1  ...              7     9.0   both         22
# 14                  1  ...              7     9.0   both         22
#
#         loyalty_flag  avg_ord_prices spending_flag  \
# 0       new_customer        6.367797   low_spender
# 1       new_customer        6.367797   low_spender
# 2       new_customer        6.367797   low_spender
# 3       new_customer        6.367797   low_spender
# 4       new_customer        6.367797   low_spender
# 5       new_customer        6.367797   low_spender
# 6       new_customer        6.367797   low_spender
# 7       new_customer        6.367797   low_spender
# 8       new_customer        6.367797   low_spender
# 9       new_customer        6.367797   low_spender
# 10  regular_customer        3.980556   low_spender
# 11  regular_customer        3.980556   low_spender
# 12  regular_customer        3.980556   low_spender
# 13  regular_customer        3.980556   low_spender
# 14  regular_customer        3.980556   low_spender
#
#     median_days_since_prior_order med_freq     customer_frequency
# 0                            20.5     20.5  non-frequent_customer
# 1                            20.5     20.5  non-frequent_customer
# 2                            20.5     20.5  non-frequent_customer
# 3                            20.5     20.5  non-frequent_customer
# 4                            20.5     20.5  non-frequent_customer
# 5                            20.5     20.5  non-frequent_customer
# 6                            20.5     20.5  non-frequent_customer
# 7                            20.5     20.5  non-frequent_customer
# 8                            20.5     20.5  non-frequent_customer
# 9                            20.5     20.5  non-frequent_customer
# 10                           10.0     10.0      frequent_customer
# 11                           10.0     10.0      frequent_customer
# 12                           10.0     10.0      frequent_customer
# 13                           10.0     10.0      frequent_customer
# 14                           10.0     10.0      frequent_customer
#
# [15 rows x 24 columns]

# %%
#value counts on spending flag
df_ords_prods_merge['customer_frequency'].value_counts(dropna=False)
# Out:
# frequent_customer        21559853
# regular_customer          7208564
# non-frequent_customer     3636437
# NaN                             5
# Name: customer_frequency, dtype: int64

# %%
#Check for shape
df_ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
#Export Data
df_ords_prods_merge.to_pickle(os.path.join(path,'02 Data','Prepared Data','orders_products_merged_aggregated.pkl'))
